# %% [markdown]
# <a href="https://colab.research.google.com/github/IlyaZutler/Dimonds/blob/main/DS_Dimond_L_R.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df_diamonds = sns.load_dataset('diamonds')
df_diamonds_orig = df_diamonds.copy()
df_diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
color_reting = pd.DataFrame({'color':['D','E','F','G','H','I','J'], 'color_rating' :[1,2,3,4,5,6,7]} )
cut_reting = pd.DataFrame({'cut':['Ideal','Premium','Very Good','Good','Fair'], 'cut_rating' :[5,4,3,2,1]} )
clarity_reting = pd.DataFrame({'clarity':['IF','VVS1','VVS2', 'VS1','VS2','SI1','SI2','I1' ], 'clarity_rating' :[1, 2, 2.5, 3, 4, 5, 6, 7]} )
color_reting
# Out:
#   color  color_rating
# 0     D             1
# 1     E             2
# 2     F             3
# 3     G             4
# 4     H             5
# 5     I             6
# 6     J             7

# %%
df_diamonds_orig = df_diamonds_orig.merge(color_reting, how='left', on='color')
df_diamonds_orig = df_diamonds_orig.merge(cut_reting, how='left', on='cut')
df_diamonds_orig = df_diamonds_orig.merge(clarity_reting, how='left', on='clarity')
df_diamonds_orig.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z  \
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
#
#    color_rating  cut_rating  clarity_rating
# 0             2           5             6.0
# 1             2           4             5.0
# 2             2           2             3.0
# 3             6           4             4.0
# 4             7           2             6.0

# %%
df_diamonds_orig['carat_sq'] = df_diamonds_orig['carat']**2
df_diamonds_orig['carat_kub'] = df_diamonds_orig['carat']**3
df_diamonds_orig['depth_sq'] = df_diamonds_orig['depth']**2
df_diamonds_orig['table_sq'] = df_diamonds_orig['table']**2
df_diamonds_orig['y_sq'] = df_diamonds_orig['y']**2
df_diamonds_orig['y_kub'] = df_diamonds_orig['y']**3
df_diamonds_orig['cut_rating_sq']=df_diamonds_orig['cut_rating']**2
df_diamonds_orig['color_rating_sq']=df_diamonds_orig['color_rating']**2
df_diamonds_orig['clarity_rating_sq']=df_diamonds_orig['clarity_rating']**2

# %%
df_diamonds_orig.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z  color_rating    cut_rating  clarity_rating  \
# count  53940.000000  53940.000000  53940.000000  53940.000000    53940.000000
# mean       5.734526      3.538734      3.594197      3.904097        4.096885
# std        1.142135      0.705699      1.701105      1.116600        1.403853
# min        0.000000      0.000000      1.000000      1.000000        1.000000
# 25%        4.720000      2.910000      2.000000      3.000000        3.000000
# 50%        5.710000      3.530000      4.000000      4.000000        4.000000
# 75%        6.540000      4.040000      5.000000      5.000000        5.000000
# max       58.900000     31.800000      7.000000      5.000000        7.000000
#
#            carat_sq     carat_kub      depth_sq      table_sq          y_sq  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.861390      1.164824   3815.041371   3306.320838     34.189235
# std        1.056506      2.374135    176.850239    260.952872     20.331614
# min        0.040000      0.008000   1849.000000   1849.000000      0.000000
# 25%        0.160000      0.064000   3721.000000   3136.000000     22.278400
# 50%        0.490000      0.343000   3819.240000   3249.000000     32.604100
# 75%        1.081600      1.124864   3906.250000   3481.000000     42.771600
# max       25.100100    125.751501   6241.000000   9025.000000   3469.210000
#
#                y_kub  cut_rating_sq  color_rating_sq  clarity_rating_sq
# count   53940.000000   53940.000000     53940.000000       53940.000000
# mean      214.646253      16.488747        15.811958          18.755237
# std       898.145207       7.931788        13.130857          11.346583
# min         0.000000       1.000000         1.000000           1.000000
# 25%       105.154048       9.000000         4.000000           9.000000
# 50%       186.169411      16.000000        16.000000          16.000000
# 75%       279.726264      25.000000        25.000000          25.000000
# max    204336.469000      25.000000        49.000000          49.000000

# %%
X = df_diamonds_orig.drop(columns=['price', 'cut', 'color','clarity'])  # these are our "features" that we use to predict from
y = df_diamonds_orig['price']  # this is what we want to learn to predict

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=100)

# %%
# prompt: нормализовать значения переменных

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#Split into training and testing sets

# Create and train the model
model_l = LinearRegression()
model_l.fit(X_train, y_train)

# Prediction
y_test_pred = model_l.predict(X_test)

# Evaluate the model
print(f'Model R^2 score: {model_l.score(X_test, y_test)}')

def RMSE(y_pred, y_true):
    return ((y_pred - y_true) ** 2).mean() ** 0.5

def summary(model):
    y_train_pred = model_l.predict(X_train)
    y_test_pred = model_l.predict(X_test)

    print("Train RMSE:", round(RMSE(y_train_pred, y_train),3))
    print("Test RMSE:", round(RMSE(y_test_pred, y_test),3))
    print("Train STD", round(y_train.std(),3))
    print("Test STD", round(y_test.std(), 3))
    return y_train_pred, y_test_pred


y_train_pred, y_test_pred = summary(model_l)
# Out:
# Model R^2 score: 0.9229652049106836
# Train RMSE: 1095.71
# Test RMSE: 1096.643
# Train STD 4005.645
# Test STD 3951.258

# %%
# prompt: коэффициенты линейной модели в порядке убывания

coefs = pd.DataFrame({
    'feature': X.columns,
    'coef': model_l.coef_
}).sort_values(by='coef', ascending=False)

print(coefs)
# Out:
#               feature         coef
# 0               carat  7926.349169
# 9            carat_sq  3245.878061
# 1               depth  1033.887711
# 7          cut_rating   421.046174
# 8      clarity_rating   339.144105
# 4                   y   246.258136
# 6        color_rating   207.001519
# 13               y_sq     3.944023
# 12           table_sq     0.506947
# 14              y_kub    -0.138235
# 11           depth_sq    -8.959908
# 5                   z   -44.202769
# 15      cut_rating_sq   -47.337634
# 16    color_rating_sq   -71.730999
# 2               table   -91.283057
# 17  clarity_rating_sq  -115.352823
# 10          carat_kub  -862.618672
# 3                   x -1286.943230
